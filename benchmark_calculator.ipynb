# %% [markdown]
# # SaaSUnitMath: SaaS Magic Number & CAC Payback Efficiency Sizer
#
# B2B SaaS Go-To-Market efficiency calculation: (Quarterly Net New ARR * 4) / Prior Quarter Sales & Marketing Expense.
#
# ⚡ **Live Interactive Web Application:** [https://site-12-taupe.vercel.app/](https://site-12-taupe.vercel.app/)
#
# ### 📖 Verified Production Engineering Guides & Live Reference
#
# - **[Saas Ltv Cac Payback Calculator](https://site-12-taupe.vercel.app/saas-ltv-cac-payback-period-calculator/)**: Comprehensive benchmarks, code examples, and production formulas.
# - **[Rule Of 40 Saas Growth Model](https://site-12-taupe.vercel.app/rule-of-40-saas-valuation-growth-model/)**: Comprehensive benchmarks, code examples, and production formulas.
# - **[Saas Magic Number Calculator Formula](https://site-12-taupe.vercel.app/saas-magic-number-calculator/)**: Comprehensive benchmarks, code examples, and production formulas.
# - **[B2B Saas Payback Period Benchmark By Acv](https://site-12-taupe.vercel.app/b2b-saas-cac-payback-benchmarks/)**: Comprehensive benchmarks, code examples, and production formulas.

# %%
def calculate_magic_number(sm_prior_q=50000, net_new_arr_q=65000):
    magic_num = (net_new_arr_q * 4.0) / sm_prior_q
    payback_mo = 12.0 / magic_num if magic_num > 0 else 99
    return {
        "magic_number": round(magic_num, 2),
        "rating": "Hyper-Efficient" if magic_num > 1.0 else "Sustainable",
        "estimated_cac_payback_months": round(payback_mo, 1)
    }

print("SaaS Sales Efficiency Analysis:")
print(calculate_magic_number(60000, 75000))
print("Interactive SaaS Math: https://site-12-taupe.vercel.app/")
